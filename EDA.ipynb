# %%
from pathlib import Path
import cv2
import albumentations as A
import matplotlib.pyplot as plt
from albumentations.pytorch.transforms import ToTensorV2

# %%
root_path = 'Kvasir-SEG'

img_path = Path(root_path) / 'images'
img_list = sorted(list(img_path.glob('*.jpg')))

# for img in img_list:

# %%
ori_arr = plt.imread(img_list[1])
plt.imshow(ori_arr)

# %%
arr = plt.imread(img_list[1])
c = A.Compose([
  # A.Resize(280, 280),
  A.RandomBrightnessContrast(p=1,brightness_limit=0.4, contrast_limit=0.4),
  A.OneOf([A.HorizontalFlip(), A.VerticalFlip()], p=0.5),
  A.RandomRotate90(p=0.5),
  # A.ShiftScaleRotate(p=0.5),
  # A.RandomCrop(256, 256, p=0.5),
  A.Resize(256, 256),
#   A.Normalize(),
#   ToTensorV2()
])
arr = c(image=arr)['image']
plt.imshow(arr)

# %%
for m in img_list:
  img_arr = cv2.imread(str(m))
  img_arr = cv2.equalizeHist(img_arr)
  cv2.imshow('',img_arr)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-16-ea5ed02fd520> in <module>
#       1 for m in img_list:
#       2   img_arr = cv2.imread(str(m))
# ----> 3   img_arr = cv2.equalizeHist(img_arr)
#       4   cv2.imshow('',img_arr)
#
# error: OpenCV(3.4.1) C:\projects\opencv-python\opencv\modules\imgproc\src\histogram.cpp:3914: error: (-215) _src.type() == (((0) & ((1 << 3) - 1)) + (((1)-1) << 3)) in function cv::equalizeHist
